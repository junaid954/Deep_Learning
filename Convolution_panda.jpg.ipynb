# %%
import numpy as np 
from PIL import Image
import matplotlib.pyplot as plt

# %%
img= Image.open("../datasets/ice.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=902x1024 at 0x2B0ABD23808>

# %%
img.size
# Out:
# (902, 1024)

# %%
small=img.resize(size=(400,300))

# %%
small
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x2B0ABD38188>

# %%
img= np.array(small).mean(axis=2)

# %%
plt.imshow(img,cmap="gray")
plt.show()

# %%
padded_image= np.pad(img, pad_width=1,mode="minimum")

# %%
padded_image.shape
# Out:
# (302, 402)

# %%
img.shape
# Out:
# (300, 400)

# %%
plt.imshow(padded_image, cmap="gray")

# %%
filt= np.array([[1,1,1],[0,0,0],[-1,-1,-1]])    # vertical filter

# %%
result=np.zeros_like(img)      # we are creating an array of zeros similar to the size of the img

# %%
for row in range (result.shape[0]):
    for col in range (result.shape[1]):
         cut = padded_image[row:row+3,col:col+3]
    result[row, col]=(cut*filt).mean()

# %%
plt.imshow(result, cmap="gray")
